# %% [markdown]
# <a href="https://colab.research.google.com/github/SimDeveloper-cripto/phpc2026/blob/main/PHPC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvcc trapezoidal_rule/main.cu trapezoidal_rule/kernels.cu -o trap.exe -O3
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./trap.exe
# Out:
# Integrazione di f(x)=x^2 da 0.000000 a 10.000000 con 10000000 trapezi.
# Block size: 256 threads
#
# Metodo 1 | Risultato: 333.333 | Tempo: 0.001223 sec
# Metodo 2 | Risultato: 333.333 | Tempo: 0.001126 sec
# Metodo 3 | Risultato: 333.333 | Tempo: 0.000413 sec

# %%
# !nvcc trapezoidal_rule/main2.cu -o trap2.exe -O3
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./trap2.exe
# Out:
# --- Risultati dell'Integrazione ---
# Risultato CPU: 333.379700 (Tempo: 1.374000 ms)
# Risultato GPU: 333.332336 (Tempo: 0.270784 ms)
# Speed-up ottenuto: 5.07x

# %%
# !nvcc coalescence_and_alignment/main_v1.cu -o exercise  && ./exercise
# !nvcc coalescence_and_alignment/main_v2.cu -o exercise2 && ./exercise2
